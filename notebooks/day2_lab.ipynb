# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TunaLee/posco/blob/main/notebooks/day2_lab.ipynb)
#
# # Day 2 · 실습 — 데이터 다루기
#
# NumPy · Pandas · 전처리 · 시각화
#
# ---
#
# ### 시작하기 전에
#
# 1. **파일 → 드라이브에 사본 저장** 을 먼저 누른다. 안 하면 고친 내용이 남지 않는다.
# 2. 셀을 고르고 **Shift + Enter** 로 실행한다.
#
# 실습 시간에 푼다. **강의 노트북에 없던 문제**들이다.
#
# `스스로 풀기` 는 각자, `조별로 풀기` 는 2~3명이 한 조로 상의하며 푼다.
# 막히면 강의 노트북(`live`)에서 같은 함수를 쓴 셀을 찾아 대조한다.
#
# 문제는 실행하면 `assert` 로 자가 채점된다. 맞으면 `통과` 가 찍히고,
# 틀리면 기대값과 실제값이 같이 나온다.

# %% [markdown]
# ## 0. NumPy

# %% [markdown]
# ### 스스로 풀기
#
# 각자 푼다. 막히면 손을 든다.

# %% [markdown]
# > **빈칸 문제 1.** `a` 에서 800 미만인 값만 골라 `low` 에 담는다. 반복문을 쓰지 않는다.

# %%
import numpy as np
a = np.array([898, 835, 760, 860, 781])
low = ___

assert list(low) == [760, 781], f'실제 {list(low)}'
print('통과')

# %% [markdown]
# > **빈칸 문제 2.** `a` 에서 800 이상인 값들의 **평균**을 `avg` 에 담는다.

# %%
import numpy as np
a = np.array([898, 835, 760, 860, 781])
avg = ___

assert abs(avg - 864.3333333333334) < 1e-9, f'실제 {avg}'
print('통과')

# %% [markdown]
# ### 조별로 풀기
#
# 2~3명이 한 조로 상의하며 푼다.

# %% [markdown]
# > **실습문제 1.** `X` 의 **각 열을 평균 0으로** 맞춘 배열을 `Z` 에 담는다.
# > 열별 평균은 `X.mean(axis=0)` 이다. 브로드캐스팅으로 한 줄에 끝난다.

# %%
import numpy as np
X = np.array([[1., 2., 3.], [5., 6., 7.]])
# 여기에 작성한다

assert np.allclose(Z.mean(axis=0), [0, 0, 0]), f'열 평균이 0이 아니다: {Z.mean(axis=0)}'
assert Z.shape == X.shape
print('통과')

# %% [markdown]
# ## 1. Pandas — 읽고 확인하기

# %% [markdown]
# ### 스스로 풀기
#
# 각자 푼다. 막히면 손을 든다.

# %% [markdown]
# > **빈칸 문제 3.** 결측이 하나라도 있는 열의 **이름 목록**을 `missing_cols` 에 담는다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
missing_cols = ___

assert sorted(missing_cols) == ['수분율', '입도'], f'실제 {missing_cols}'
print('통과')

# %% [markdown]
# > **빈칸 문제 4.** `raw['설비호기']` 의 공백과 대소문자를 정리한 뒤, **몇 종류가 남는지** `n_kind` 에 담는다.
# > `value_counts()` 결과의 길이를 센다.

# %%
import pandas as pd
raw = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv')
n_kind = ___

assert n_kind == 6, f'기대 6, 실제 {n_kind}'
print('통과')

# %% [markdown]
# ## 2. Pandas — 고르고 계산하기

# %% [markdown]
# ### 스스로 풀기
#
# 각자 푼다. 막히면 손을 든다.

# %% [markdown]
# > **빈칸 문제 5.** `소성온도` 가 900 이상이면서 양품인 배치 수를 `n` 에 담는다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
n = ___

assert n == 65, f'기대 65, 실제 {n}'
print('통과')

# %% [markdown]
# > **빈칸 문제 6.** `loc` 로 불량 배치의 `방전용량` 만 뽑아 평균을 `avg` 에 담는다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
avg = ___

assert abs(avg - 164.5) < 1.0, f'실제 {avg}'
print('통과')

# %% [markdown]
# > **빈칸 문제 7.** `불순물` 을 퍼센트로 바꾼 열 `impurity_pct` 를 만든다. ppm ÷ 10000 이다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
df['impurity_pct'] = ___

assert abs(df['impurity_pct'].mean() - 0.0829) < 0.001, f"실제 {df['impurity_pct'].mean()}"
print('통과')

# %% [markdown]
# ## 4. 전처리

# %% [markdown]
# ### 스스로 풀기
#
# 각자 푼다. 막히면 손을 든다.

# %% [markdown]
# > **빈칸 문제 8.** `설비호기` 와 `교대조` 를 원-핫으로 바꾼 표를 `d` 에 담는다. 첫 범주는 뺀다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
d = ___

cols = [c for c in d.columns if c.startswith(('설비호기_', '교대조_'))]
assert len(cols) == 6, f'기대 6개, 실제 {len(cols)}: {cols}'
assert '설비호기_A' not in cols, 'drop_first=True 면 설비호기_A 는 빠진다'
print('통과')

# %% [markdown]
# ### 조별로 풀기
#
# 2~3명이 한 조로 상의하며 푼다.

# %% [markdown]
# > **실습문제 2.** 위 전처리를 **함수 하나로** 묶는다. `prep(url)` 이 `X_tr, X_te, y_tr, y_te` 를 돌려준다.
# > 결측 채우기 → 원-핫 → 분할 → 스케일링 순서를 지킨다.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
URL = 'https://tunalee.github.io/posco/data/batch_quality.csv'
# 여기에 작성한다

a, b, c, d_ = prep(URL)
assert a.shape[1] == b.shape[1], '훈련셋과 테스트셋의 열 수가 달라졌다'
assert len(a) > len(b), '훈련셋이 더 커야 한다'
assert abs((1 - c.mean()) - (1 - d_.mean())) < 0.02, 'stratify 로 비율을 맞춘다'
print('통과')

# %% [markdown]
# ## 5. 시각화

# %% [markdown]
# ### 스스로 풀기
#
# 각자 푼다. 막히면 손을 든다.

# %% [markdown]
# > **빈칸 문제 9.** `방전용량` 와 상관이 **가장 강한 열**의 이름을 `best` 에 담는다.
# 자기 자신은 뺀다. 가장 큰 양수를 고르면 된다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
c = df.corr(numeric_only=True)['방전용량'].drop('방전용량')
best = ___

assert best == '소성온도', f'기대 소성온도, 실제 {best}'
print('통과')

# %% [markdown]
# ### 조별로 풀기
#
# 2~3명이 한 조로 상의하며 푼다.

# %% [markdown]
# > **실습문제 3.** 설비별 `방전용량` 분포를 **박스플롯**으로 그리고,
# 이상치가 가장 많이 튀어나온 열이 무엇인지 눈으로 확인한다.
# > `sns.boxplot(data=df, x='설비호기', y='방전용량')`

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
import seaborn as sns
import matplotlib.pyplot as plt
# 여기에 작성한다

print('통과 — 그림이 그려졌으면 된다')

# %% [markdown]
# > **실습문제 4.** `성형압력` 에는 센서 오류값 999 가 섞여 있다.
# **999 를 결측으로 바꾼 뒤** 중앙값으로 채우고, 바꾸기 전후의 평균을 둘 다 출력한다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
# 여기에 작성한다

assert before > 30, f'바꾸기 전 평균은 999 탓에 커야 한다: {before}'
assert 23 < after < 25, f'바꾼 뒤 평균은 24 근처: {after}'
print('통과')

# %% [markdown]
# ## 6. 종합 문제

# %% [markdown]
# ### 조별로 풀기
#
# 2~3명이 한 조로 상의하며 푼다.

# %% [markdown]
# > **빈칸 문제 10.** **야간조의 불량률**과 **주간조의 불량률** 차이를 `gap` 에 담는다.
# 야간 − 주간 순서로 뺀다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
rate = ___
gap = ___

assert gap > 0, '야간조 불량률이 더 높다'
assert abs(gap - 0.035) < 0.01, f'실제 {gap}'
print('통과')

# %% [markdown]
# > **빈칸 문제 11.** 온도를 10도 구간으로 묶어 구간별 **평균 용량**을 `band_avg` 에 담는다.
# > `(df['소성온도'] // 10 * 10)` 으로 구간 열을 만든다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
df['band'] = ___
band_avg = ___

assert band_avg.idxmax() >= 880, f'용량이 가장 높은 구간은 880 이상: {band_avg.idxmax()}'
print('통과')

# %% [markdown]
# > **실습문제 5.** **불량이 가장 많이 나온 조건 조합**을 찾는다.
# 설비와 교대조로 묶어 불량 건수를 세고, 가장 많은 조합을 `worst` 에 담는다.
# > 결과는 `('A', 'night')` 같은 튜플이다.

# %%
import pandas as pd
df = pd.read_csv('https://tunalee.github.io/posco/data/batch_quality.csv', thousands=',', na_values=['N/A', '-'])
df['설비호기'] = df['설비호기'].str.strip().str.upper()
# 여기에 작성한다

assert isinstance(worst, tuple) and len(worst) == 2, f'튜플이어야 한다: {worst}'
assert worst[0] in list('ABCDEF') and worst[1] in ('day', 'night')
print('통과')
